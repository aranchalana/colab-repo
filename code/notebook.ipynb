# %%
import pandas as pd

# Read the file data/attacks.csv
# Specify encoding to avoid utf-8 decode error
df = pd.read_csv("/home/ralcaraz/Documentos/git-projects/colab-repo/data/attacks.csv", encoding='latin1')
# Drop the na rows
# df = df.dropna().reset_index(drop=True)
df[df.Area == "Majorca"]
# Out:
#       Case Number         Date    Year        Type Country     Area  \
# 113  2017.07.23.a  23-Jul-2017  2017.0  Unprovoked   SPAIN  Majorca
#
#                            Location  Activity    Name Sex   ...  \
# 113  Estanys Beach, Colonia de Sant  Swimming  female    F  ...
#
#           Species    Investigator or Source                       pdf  \
# 113  Blue shark 6'  Daily Record, 7/24/2017  2017.07.23.a-Majorca.pdf
#
#                                           href formula  \
# 113  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href Case Number.1  \
# 113  http://sharkattackfile.net/spreadsheets/pdf_di...  2017.07.23.a
#
#     Case Number.2 original order Unnamed: 22 Unnamed: 23
# 113  2017.07.23.a         6190.0         NaN         NaN
#
# [1 rows x 24 columns]
